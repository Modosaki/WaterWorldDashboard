# %%
from sqlalchemy import create_engine
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine

#engine = create_engine('sqlite:///C:/Users/8135t/Desktop/Project2-WaterWorld/waterdb.sqlite', echo=False)

# %%
from flask import Flask, jsonify, render_template
from flask_sqlalchemy import SQLAlchemy

# %%
engine = create_engine('sqlite:///C:/Users/8135t/Desktop/Project2-WaterWorld/tao-branch/db/waterdb.sqlite', echo=False)

# %%
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# %%
Base.classes.keys()
# Out:
# ['Aquastat_table', 'WQI_table']

# %%
WQI_table = Base.classes.WQI_table
Aquastat_table = Base.classes.Aquastat_table

# %%
session = Session(engine)

# %%
results = session.query(WQI_table.iso, WQI_table.country, WQI_table.H2O_current).limit(10).all()

# %%
for result in results:
    print(result)
# Out:
# ('AFG', 'Afghanistan', 25.75)
# ('ALB', 'Albania', 66.56)
# ('DZA', 'Algeria', 60.26)
# ('AGO', 'Angola', 9.2)
# ('ATG', 'Antigua and Barbuda', 53.33)
# ('ARG', 'Argentina', 73.07)
# ('ARM', 'Armenia', 61.94)
# ('AUS', 'Australia', 98.44)
# ('AUT', 'Austria', 94.63)
# ('AZE', 'Azerbaijan', 48.53)

# %%
aqua_results = session.query(Aquastat_table.country, Aquastat_table.Variable,
                             Aquastat_table.Year, Aquastat_table.Value,
                             Aquastat_table.unit, Aquastat_table.iso).limit(10).all()

# %%
for result in aqua_results:
    print(result)
# Out:
# ('Afghanistan', 'Total population', 1962, 9344.0, 'E', 'AFG')
# ('Afghanistan', 'Total population', 1967, 10369.0, 'E', 'AFG')
# ('Afghanistan', 'Total population', 1972, 11717.0, 'E', 'AFG')
# ('Afghanistan', 'Total population', 1977, 13056.0, 'E', 'AFG')
# ('Afghanistan', 'Total population', 1982, 12667.0, 'E', 'AFG')
# ('Afghanistan', 'Total population', 1987, 11338.0, 'E', 'AFG')
# ('Afghanistan', 'Total population', 1992, 13746.0, 'E', 'AFG')
# ('Afghanistan', 'Total population', 1997, 18034.0, 'E', 'AFG')
# ('Afghanistan', 'Total population', 2002, 21487.0, 'E', 'AFG')
# ('Afghanistan', 'Total population', 2007, 25878.0, 'E', 'AFG')

# %%
stmt = session.query(Aquastat_table).statement

# %%
import pandas as pd

# %%
aqua_df = pd.read_sql_query(stmt, session.bind)

# %%
stmt_wqi = session.query(WQI_table).statement

# %%
wqi_df = pd.read_sql_query(stmt_wqi, session.bind)

# %%
iso_country_df = aqua_df.drop_duplicates('iso')
iso_country_df =iso_country_df[['country','iso']]

# %%
iso_country_df
# Out:
#                                         country  iso
# 0                                   Afghanistan  AFG
# 54                                      Albania  ALB
# 106                                     Algeria  DZA
# 160                                     Andorra  AND
# 214                                      Angola  AGO
# 268                         Antigua and Barbuda  ATG
# 322                                   Argentina  ARG
# 377                                     Armenia  ARM
# 414                                   Australia  AUS
# 468                                     Austria  AUT
# 522                                  Azerbaijan  AZE
# 558                                     Bahamas  BHS
# 609                                     Bahrain  BHR
# 663                                  Bangladesh  BGD
# 717                                    Barbados  BRB
# 771                                     Belarus  BLR
# 807                                     Belgium  BEL
# 853                                      Belize  BLZ
# 907                                       Benin  BEN
# 961                                      Bhutan  BTN
# 1015           Bolivia (Plurinational State of)  BOL
# 1069                     Bosnia and Herzegovina  BIH
# 1105                                   Botswana  BWA
# 1159                                     Brazil  BRA
# 1213                          Brunei Darussalam  BRN
# 1249                                   Bulgaria  BGR
# 1303                               Burkina Faso  BFA
# 1359                                    Burundi  BDI
# 1413                                 Cabo Verde  CPV
# 1467                                   Cambodia  KHM
# ...                                         ...  ...
# 8490                                   Suriname  SUR
# 8542                                     Sweden  SWE
# 8596                                Switzerland  CHE
# 8650                       Syrian Arab Republic  SYR
# 8704                                 Tajikistan  TJK
# 8737                                   Thailand  THA
# 8792  The former Yugoslav Republic of Macedonia  MKD
# 8828                                Timor-Leste  TLS
# 8879                                       Togo  TGO
# 8933                                    Tokelau  TKL
# 8981                                      Tonga  TON
# 9035                        Trinidad and Tobago  TTO
# 9089                                    Tunisia  TUN
# 9143                                     Turkey  TUR
# 9197                               Turkmenistan  TKM
# 9225                                     Tuvalu  TUV
# 9279                                     Uganda  UGA
# 9333                                    Ukraine  UKR
# 9367                       United Arab Emirates  ARE
# 9421                             United Kingdom  GBR
# 9475                United Republic of Tanzania  TZA
# 9529                   United States of America  USA
# 9583                                    Uruguay  URY
# 9637                                 Uzbekistan  UZB
# 9672                                    Vanuatu  VUT
# 9726         Venezuela (Bolivarian Republic of)  VEN
# 9781                                   Viet Nam  VNM
# 9836                                      Yemen  YEM
# 9887                                     Zambia  ZMB
# 9941                                   Zimbabwe  ZWE
#
# [200 rows x 2 columns]

# %%
iso_country_dict =iso_country_df.to_dict('records')

# %%
iso_country_dict
# Out:
# [{'country': 'Afghanistan', 'iso': 'AFG'},
#  {'country': 'Albania', 'iso': 'ALB'},
#  {'country': 'Algeria', 'iso': 'DZA'},
#  {'country': 'Andorra', 'iso': 'AND'},
#  {'country': 'Angola', 'iso': 'AGO'},
#  {'country': 'Antigua and Barbuda', 'iso': 'ATG'},
#  {'country': 'Argentina', 'iso': 'ARG'},
#  {'country': 'Armenia', 'iso': 'ARM'},
#  {'country': 'Australia', 'iso': 'AUS'},
#  {'country': 'Austria', 'iso': 'AUT'},
#  {'country': 'Azerbaijan', 'iso': 'AZE'},
#  {'country': 'Bahamas', 'iso': 'BHS'},
#  {'country': 'Bahrain', 'iso': 'BHR'},
#  {'country': 'Bangladesh', 'iso': 'BGD'},
#  {'country': 'Barbados', 'iso': 'BRB'},
#  {'country': 'Belarus', 'iso': 'BLR'},
#  {'country': 'Belgium', 'iso': 'BEL'},
#  {'country': 'Belize', 'iso': 'BLZ'},
#  {'country': 'Benin', 'iso': 'BEN'},
#  {'country': 'Bhutan', 'iso': 'BTN'},
#  {'country': 'Bolivia (Plurinational State of)', 'iso': 'BOL'},
#  {'country': 'Bosnia and Herzegovina', 'iso': 'BIH'},
#  {'country': 'Botswana', 'iso': 'BWA'},
#  {'country': 'Brazil', 'iso': 'BRA'},
#  {'country': 'Brunei Darussalam', 'iso': 'BRN'},
#  {'country': 'Bulgaria', 'iso': 'BGR'},
#  {'country': 'Burkina Faso', 'iso': 'BFA'},
#  {'country': 'Burundi', 'iso': 'BDI'},
#  {'country': 'Cabo Verde', 'iso': 'CPV'},
#  {'country': 'Cambodia', 'iso': 'KHM'},
#  {'country': 'Cameroon', 'iso': 'CMR'},
#  {'country': 'Canada', 'iso': 'CAN'},
#  {'country': 'Central African Republic', 'iso': 'CAF'},
#  {'country': 'Chad', 'iso': 'TCD'},
#  {'country': 'Chile', 'iso': 'CHL'},
#  {'country': 'China', 'iso': 'CHN'},
#  {'country': 'Colombia', 'iso': 'COL'},
#  {'country': 'Comoros', 'iso': 'COM'},
#  {'country': 'Congo', 'iso': 'COG'},
#  {'country': 'Cook Islands', 'iso': 'COK'},
#  {'country': 'Costa Rica', 'iso': 'CRI'},
#  {'country': "Côte d'Ivoire", 'iso': 'CIV'},
#  {'country': 'Croatia', 'iso': 'HRV'},
#  {'country': 'Cuba', 'iso': 'CUB'},
#  {'country': 'Cyprus', 'iso': 'CYP'},
#  {'country': 'Czechia', 'iso': 'CZE'},
#  {'country': "Democratic People's Republic of Korea", 'iso': 'PRK'},
#  {'country': 'Democratic Republic of the Congo', 'iso': 'COD'},
#  {'country': 'Denmark', 'iso': 'DNK'},
#  {'country': 'Djibouti', 'iso': 'DJI'},
#  {'country': 'Dominica', 'iso': 'DMA'},
#  {'country': 'Dominican Republic', 'iso': 'DOM'},
#  {'country': 'Ecuador', 'iso': 'ECU'},
#  {'country': 'Egypt', 'iso': 'EGY'},
#  {'country': 'El Salvador', 'iso': 'SLV'},
#  {'country': 'Equatorial Guinea', 'iso': 'GNQ'},
#  {'country': 'Eritrea', 'iso': 'ERI'},
#  {'country': 'Estonia', 'iso': 'EST'},
#  {'country': 'Eswatini', 'iso': 'SWZ'},
#  {'country': 'Ethiopia', 'iso': 'ETH'},
#  {'country': 'Faroe Islands', 'iso': 'FRO'},
#  {'country': 'Fiji', 'iso': 'FJI'},
#  {'country': 'Finland', 'iso': 'FIN'},
#  {'country': 'France', 'iso': 'FRA'},
#  {'country': 'Gabon', 'iso': 'GAB'},
#  {'country': 'Gambia', 'iso': 'GMB'},
#  {'country': 'Georgia', 'iso': 'GEO'},
#  {'country': 'Germany', 'iso': 'DEU'},
#  {'country': 'Ghana', 'iso': 'GHA'},
#  {'country': 'Greece', 'iso': 'GRC'},
#  {'country': 'Grenada', 'iso': 'GRD'},
#  {'country': 'Guatemala', 'iso': 'GTM'},
#  {'country': 'Guinea', 'iso': 'GIN'},
#  {'country': 'Guinea-Bissau', 'iso': 'GNB'},
#  {'country': 'Guyana', 'iso': 'GUY'},
#  {'country': 'Haiti', 'iso': 'HTI'},
#  {'country': 'Holy See', 'iso': 'VAT'},
#  {'country': 'Honduras', 'iso': 'HND'},
#  {'country': 'Hungary', 'iso': 'HUN'},
#  {'country': 'Iceland', 'iso': 'ISL'},
#  {'country': 'India', 'iso': 'IND'},
#  {'country': 'Indonesia', 'iso': 'IDN'},
#  {'country': 'Iran (Islamic Republic of)', 'iso': 'IRN'},
#  {'country': 'Iraq', 'iso': 'IRQ'},
#  {'country': 'Ireland', 'iso': 'IRL'},
#  {'country': 'Israel', 'iso': 'ISR'},
#  {'country': 'Italy', 'iso': 'ITA'},
#  {'country': 'Jamaica', 'iso': 'JAM'},
#  {'country': 'Japan', 'iso': 'JPN'},
#  {'country': 'Jordan', 'iso': 'JOR'},
#  {'country': 'Kazakhstan', 'iso': 'KAZ'},
#  {'country': 'Kenya', 'iso': 'KEN'},
#  {'country': 'Kiribati', 'iso': 'KIR'},
#  {'country': 'Kuwait', 'iso': 'KWT'},
#  {'country': 'Kyrgyzstan', 'iso': 'KGZ'},
#  {'country': "Lao People's Democratic Republic", 'iso': 'LAO'},
#  {'country': 'Latvia', 'iso': 'LVA'},
#  {'country': 'Lebanon', 'iso': 'LBN'},
#  {'country': 'Lesotho', 'iso': 'LSO'},
#  {'country': 'Liberia', 'iso': 'LBR'},
#  {'country': 'Libya', 'iso': 'LBY'},
#  {'country': 'Liechtenstein', 'iso': 'LIE'},
#  {'country': 'Lithuania', 'iso': 'LTU'},
#  {'country': 'Luxembourg', 'iso': 'LUX'},
#  {'country': 'Madagascar', 'iso': 'MDG'},
#  {'country': 'Malawi', 'iso': 'MWI'},
#  {'country': 'Malaysia', 'iso': 'MYS'},
#  {'country': 'Maldives', 'iso': 'MDV'},
#  {'country': 'Mali', 'iso': 'MLI'},
#  {'country': 'Malta', 'iso': 'MLT'},
#  {'country': 'Marshall Islands', 'iso': 'MHL'},
#  {'country': 'Mauritania', 'iso': 'MRT'},
#  {'country': 'Mauritius', 'iso': 'MUS'},
#  {'country': 'Mexico', 'iso': 'MEX'},
#  {'country': 'Micronesia (Federated States of)', 'iso': 'FSM'},
#  {'country': 'Monaco', 'iso': 'MCO'},
#  {'country': 'Mongolia', 'iso': 'MNG'},
#  {'country': 'Montenegro', 'iso': 'MNE'},
#  {'country': 'Morocco', 'iso': 'MAR'},
#  {'country': 'Mozambique', 'iso': 'MOZ'},
#  {'country': 'Myanmar', 'iso': 'MMR'},
#  {'country': 'Namibia', 'iso': 'NAM'},
#  {'country': 'Nauru', 'iso': 'NRU'},
#  {'country': 'Nepal', 'iso': 'NPL'},
#  {'country': 'Netherlands', 'iso': 'NLD'},
#  {'country': 'New Zealand', 'iso': 'NZL'},
#  {'country': 'Nicaragua', 'iso': 'NIC'},
#  {'country': 'Niger', 'iso': 'NER'},
#  {'country': 'Nigeria', 'iso': 'NGA'},
#  {'country': 'Niue', 'iso': 'NIU'},
#  {'country': 'Norway', 'iso': 'NOR'},
#  {'country': 'Occupied Palestinian Territory', 'iso': 'PSE'},
#  {'country': 'Oman', 'iso': 'OMN'},
#  {'country': 'Pakistan', 'iso': 'PAK'},
#  {'country': 'Palau', 'iso': 'PLW'},
#  {'country': 'Panama', 'iso': 'PAN'},
#  {'country': 'Papua New Guinea', 'iso': 'PNG'},
#  {'country': 'Paraguay', 'iso': 'PRY'},
#  {'country': 'Peru', 'iso': 'PER'},
#  {'country': 'Philippines', 'iso': 'PHL'},
#  {'country': 'Poland', 'iso': 'POL'},
#  {'country': 'Portugal', 'iso': 'PRT'},
#  {'country': 'Puerto Rico', 'iso': 'PRI'},
#  {'country': 'Qatar', 'iso': 'QAT'},
#  {'country': 'Republic of Korea', 'iso': 'KOR'},
#  {'country': 'Republic of Moldova', 'iso': 'MDA'},
#  {'country': 'Romania', 'iso': 'ROU'},
#  {'country': 'Russian Federation', 'iso': 'RUS'},
#  {'country': 'Rwanda', 'iso': 'RWA'},
#  {'country': 'Saint Kitts and Nevis', 'iso': 'KNA'},
#  {'country': 'Saint Lucia', 'iso': 'LCA'},
#  {'country': 'Saint Vincent and the Grenadines', 'iso': 'VCT'},
#  {'country': 'Samoa', 'iso': 'WSM'},
#  {'country': 'San Marino', 'iso': 'SMR'},
#  {'country': 'Sao Tome and Principe', 'iso': 'STP'},
#  {'country': 'Saudi Arabia', 'iso': 'SAU'},
#  {'country': 'Senegal', 'iso': 'SEN'},
#  {'country': 'Serbia', 'iso': 'SRB'},
#  {'country': 'Seychelles', 'iso': 'SYC'},
#  {'country': 'Sierra Leone', 'iso': 'SLE'},
#  {'country': 'Singapore', 'iso': 'SGP'},
#  {'country': 'Slovakia', 'iso': 'SVK'},
#  {'country': 'Slovenia', 'iso': 'SVN'},
#  {'country': 'Solomon Islands', 'iso': 'SLB'},
#  {'country': 'Somalia', 'iso': 'SOM'},
#  {'country': 'South Africa', 'iso': 'ZAF'},
#  {'country': 'South Sudan', 'iso': 'SSD'},
#  {'country': 'Spain', 'iso': 'ESP'},
#  {'country': 'Sri Lanka', 'iso': 'LKA'},
#  {'country': 'Sudan', 'iso': 'SDN'},
#  {'country': 'Suriname', 'iso': 'SUR'},
#  {'country': 'Sweden', 'iso': 'SWE'},
#  {'country': 'Switzerland', 'iso': 'CHE'},
#  {'country': 'Syrian Arab Republic', 'iso': 'SYR'},
#  {'country': 'Tajikistan', 'iso': 'TJK'},
#  {'country': 'Thailand', 'iso': 'THA'},
#  {'country': 'The former Yugoslav Republic of Macedonia', 'iso': 'MKD'},
#  {'country': 'Timor-Leste', 'iso': 'TLS'},
#  {'country': 'Togo', 'iso': 'TGO'},
#  {'country': 'Tokelau', 'iso': 'TKL'},
#  {'country': 'Tonga', 'iso': 'TON'},
#  {'country': 'Trinidad and Tobago', 'iso': 'TTO'},
#  {'country': 'Tunisia', 'iso': 'TUN'},
#  {'country': 'Turkey', 'iso': 'TUR'},
#  {'country': 'Turkmenistan', 'iso': 'TKM'},
#  {'country': 'Tuvalu', 'iso': 'TUV'},
#  {'country': 'Uganda', 'iso': 'UGA'},
#  {'country': 'Ukraine', 'iso': 'UKR'},
#  {'country': 'United Arab Emirates', 'iso': 'ARE'},
#  {'country': 'United Kingdom', 'iso': 'GBR'},
#  {'country': 'United Republic of Tanzania', 'iso': 'TZA'},
#  {'country': 'United States of America', 'iso': 'USA'},
#  {'country': 'Uruguay', 'iso': 'URY'},
#  {'country': 'Uzbekistan', 'iso': 'UZB'},
#  {'country': 'Vanuatu', 'iso': 'VUT'},
#  {'country': 'Venezuela (Bolivarian Republic of)', 'iso': 'VEN'},
#  {'country': 'Viet Nam', 'iso': 'VNM'},
#  {'country': 'Yemen', 'iso': 'YEM'},
#  {'country': 'Zambia', 'iso': 'ZMB'},
#  {'country': 'Zimbabwe', 'iso': 'ZWE'}]

# %%
list(aqua_df.iso.unique())
# Out:
# ['AFG',
#  'ALB',
#  'DZA',
#  'AND',
#  'AGO',
#  'ATG',
#  'ARG',
#  'ARM',
#  'AUS',
#  'AUT',
#  'AZE',
#  'BHS',
#  'BHR',
#  'BGD',
#  'BRB',
#  'BLR',
#  'BEL',
#  'BLZ',
#  'BEN',
#  'BTN',
#  'BOL',
#  'BIH',
#  'BWA',
#  'BRA',
#  'BRN',
#  'BGR',
#  'BFA',
#  'BDI',
#  'CPV',
#  'KHM',
#  'CMR',
#  'CAN',
#  'CAF',
#  'TCD',
#  'CHL',
#  'CHN',
#  'COL',
#  'COM',
#  'COG',
#  'COK',
#  'CRI',
#  'CIV',
#  'HRV',
#  'CUB',
#  'CYP',
#  'CZE',
#  'PRK',
#  'COD',
#  'DNK',
#  'DJI',
#  'DMA',
#  'DOM',
#  'ECU',
#  'EGY',
#  'SLV',
#  'GNQ',
#  'ERI',
#  'EST',
#  'SWZ',
#  'ETH',
#  'FRO',
#  'FJI',
#  'FIN',
#  'FRA',
#  'GAB',
#  'GMB',
#  'GEO',
#  'DEU',
#  'GHA',
#  'GRC',
#  'GRD',
#  'GTM',
#  'GIN',
#  'GNB',
#  'GUY',
#  'HTI',
#  'VAT',
#  'HND',
#  'HUN',
#  'ISL',
#  'IND',
#  'IDN',
#  'IRN',
#  'IRQ',
#  'IRL',
#  'ISR',
#  'ITA',
#  'JAM',
#  'JPN',
#  'JOR',
#  'KAZ',
#  'KEN',
#  'KIR',
#  'KWT',
#  'KGZ',
#  'LAO',
#  'LVA',
#  'LBN',
#  'LSO',
#  'LBR',
#  'LBY',
#  'LIE',
#  'LTU',
#  'LUX',
#  'MDG',
#  'MWI',
#  'MYS',
#  'MDV',
#  'MLI',
#  'MLT',
#  'MHL',
#  'MRT',
#  'MUS',
#  'MEX',
#  'FSM',
#  'MCO',
#  'MNG',
#  'MNE',
#  'MAR',
#  'MOZ',
#  'MMR',
#  'NAM',
#  'NRU',
#  'NPL',
#  'NLD',
#  'NZL',
#  'NIC',
#  'NER',
#  'NGA',
#  'NIU',
#  'NOR',
#  'PSE',
#  'OMN',
#  'PAK',
#  'PLW',
#  'PAN',
#  'PNG',
#  'PRY',
#  'PER',
#  'PHL',
#  'POL',
#  'PRT',
#  'PRI',
#  'QAT',
#  'KOR',
#  'MDA',
#  'ROU',
#  'RUS',
#  'RWA',
#  'KNA',
#  'LCA',
#  'VCT',
#  'WSM',
#  'SMR',
#  'STP',
#  'SAU',
#  'SEN',
#  'SRB',
#  'SYC',
#  'SLE',
#  'SGP',
#  'SVK',
#  'SVN',
#  'SLB',
#  'SOM',
#  'ZAF',
#  'SSD',
#  'ESP',
#  'LKA',
#  'SDN',
#  'SUR',
#  'SWE',
#  'CHE',
#  'SYR',
#  'TJK',
#  'THA',
#  'MKD',
#  'TLS',
#  'TGO',
#  'TKL',
#  'TON',
#  'TTO',
#  'TUN',
#  'TUR',
#  'TKM',
#  'TUV',
#  'UGA',
#  'UKR',
#  'ARE',
#  'GBR',
#  'TZA',
#  'USA',
#  'URY',
#  'UZB',
#  'VUT',
#  'VEN',
#  'VNM',
#  'YEM',
#  'ZMB',
#  'ZWE']

# %%
sel = [
        Aquastat_table.country,
        Aquastat_table.Variable,
        Aquastat_table.Year,
        Aquastat_table.Value,
        Aquastat_table.unit,
        Aquastat_table.iso,
    ]

# %%
afg_stmt = session.query(*sel).filter(Aquastat_table.iso == 'AFG').statement

# %%
afg_df = pd.read_sql_query(afg_stmt,session.bind)

# %%
afg_df
# Out:
#         country                                           Variable  Year  \
# 0   Afghanistan                                   Total population  1962
# 1   Afghanistan                                   Total population  1967
# 2   Afghanistan                                   Total population  1972
# 3   Afghanistan                                   Total population  1977
# 4   Afghanistan                                   Total population  1982
# 5   Afghanistan                                   Total population  1987
# 6   Afghanistan                                   Total population  1992
# 7   Afghanistan                                   Total population  1997
# 8   Afghanistan                                   Total population  2002
# 9   Afghanistan                                   Total population  2007
# 10  Afghanistan                                   Total population  2012
# 11  Afghanistan                                   Total population  2015
# 12  Afghanistan                                   Urban population  1962
# 13  Afghanistan                                   Urban population  1967
# 14  Afghanistan                                   Urban population  1972
# 15  Afghanistan                                   Urban population  1977
# 16  Afghanistan                                   Urban population  1982
# 17  Afghanistan                                   Urban population  1987
# 18  Afghanistan                                   Urban population  1992
# 19  Afghanistan                                   Urban population  1997
# 20  Afghanistan                                   Urban population  2002
# 21  Afghanistan                                   Urban population  2007
# 22  Afghanistan                                   Urban population  2012
# 23  Afghanistan                                   Urban population  2015
# 24  Afghanistan                                 Population density  1962
# 25  Afghanistan                                 Population density  1967
# 26  Afghanistan                                 Population density  1972
# 27  Afghanistan                                 Population density  1977
# 28  Afghanistan                                 Population density  1982
# 29  Afghanistan                                 Population density  1987
# 30  Afghanistan                                 Population density  1992
# 31  Afghanistan                                 Population density  1997
# 32  Afghanistan                                 Population density  2002
# 33  Afghanistan                                 Population density  2007
# 34  Afghanistan                                 Population density  2012
# 35  Afghanistan                                 Population density  2015
# 36  Afghanistan  Total population with access to safe drinking-...  1992
# 37  Afghanistan  Total population with access to safe drinking-...  1997
# 38  Afghanistan  Total population with access to safe drinking-...  2002
# 39  Afghanistan  Total population with access to safe drinking-...  2007
# 40  Afghanistan  Total population with access to safe drinking-...  2012
# 41  Afghanistan  Total population with access to safe drinking-...  2015
# 42  Afghanistan  Rural population with access to safe drinking-...  1992
# 43  Afghanistan  Rural population with access to safe drinking-...  1997
# 44  Afghanistan  Rural population with access to safe drinking-...  2002
# 45  Afghanistan  Rural population with access to safe drinking-...  2007
# 46  Afghanistan  Rural population with access to safe drinking-...  2012
# 47  Afghanistan  Rural population with access to safe drinking-...  2015
# 48  Afghanistan  Urban population with access to safe drinking-...  1992
# 49  Afghanistan  Urban population with access to safe drinking-...  1997
# 50  Afghanistan  Urban population with access to safe drinking-...  2002
# 51  Afghanistan  Urban population with access to safe drinking-...  2007
# 52  Afghanistan  Urban population with access to safe drinking-...  2012
# 53  Afghanistan  Urban population with access to safe drinking-...  2015
#
#        Value unit  iso
# 0    9344.00    E  AFG
# 1   10369.00    E  AFG
# 2   11717.00    E  AFG
# 3   13056.00    E  AFG
# 4   12667.00    E  AFG
# 5   11338.00    E  AFG
# 6   13746.00    E  AFG
# 7   18034.00    E  AFG
# 8   21487.00    E  AFG
# 9   25878.00    E  AFG
# 10  29727.00    E  AFG
# 11  32527.00    E  AFG
# 12    804.90    E  AFG
# 13   1066.00    E  AFG
# 14   1434.00    E  AFG
# 15   1888.00    E  AFG
# 16   2045.00    E  AFG
# 17   1935.00    E  AFG
# 18   2608.00    E  AFG
# 19   3872.00    E  AFG
# 20   4866.00    E  AFG
# 21   6215.00    E  AFG
# 22   7596.00    E  AFG
# 23   8547.00    E  AFG
# 24     14.31    E  AFG
# 25     15.88    E  AFG
# 26     17.95    E  AFG
# 27     20.00    E  AFG
# 28     19.40    E  AFG
# 29     17.37    E  AFG
# 30     21.06    E  AFG
# 31     27.62    E  AFG
# 32     32.91    E  AFG
# 33     39.64    E  AFG
# 34     45.53    E  AFG
# 35     49.82    E  AFG
# 36     21.30    E  AFG
# 37     25.00    E  AFG
# 38     33.80    E  AFG
# 39     42.60    E  AFG
# 40     51.60    E  AFG
# 41     55.30    E  AFG
# 42     16.20    E  AFG
# 43     19.50    E  AFG
# 44     27.60    E  AFG
# 45     35.60    E  AFG
# 46     43.70    E  AFG
# 47     47.00    E  AFG
# 48     43.00    E  AFG
# 49     46.70    E  AFG
# 50     55.90    E  AFG
# 51     65.20    E  AFG
# 52     74.50    E  AFG
# 53     78.20    E  AFG

# %%
sample_dict={}
sample_dict['country']=afg_df['country'].iloc[0]
sample_dict['iso']=afg_df['iso'].iloc[0]

for stuff, stuff2 in afg_df.groupby(['country','Variable'],as_index=True):
#     print(f'{stuff[0]} and {stuff[1]}')
    data={}
    data['Year'] = list(stuff2.Year)
    data['Value'] = list(stuff2.Value)
#     print('----------------------------')
#     print(list(stuff2.Year))
#     print(list(stuff2.Value))
#     print('############################')
    sample_dict[stuff[1]]=data

# %%
sample_dict
# Out:
# {'country': 'Afghanistan',
#  'iso': 'AFG',
#  'Population density': {'Year': [1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    2012,
#    2015],
#   'Value': [14.31,
#    15.88,
#    17.95,
#    20.0,
#    19.4,
#    17.37,
#    21.06,
#    27.62,
#    32.91,
#    39.64,
#    45.53,
#    49.82]},
#  'Rural population with access to safe drinking-water (JMP)': {'Year': [1992,
#    1997,
#    2002,
#    2007,
#    2012,
#    2015],
#   'Value': [16.2, 19.5, 27.6, 35.6, 43.7, 47.0]},
#  'Total population': {'Year': [1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    2012,
#    2015],
#   'Value': [9344.0,
#    10369.0,
#    11717.0,
#    13056.0,
#    12667.0,
#    11338.0,
#    13746.0,
#    18034.0,
#    21487.0,
#    25878.0,
#    29727.0,
#    32527.0]},
#  'Total population with access to safe drinking-water (JMP)': {'Year': [1992,
#    1997,
#    2002,
#    2007,
#    2012,
#    2015],
#   'Value': [21.3, 25.0, 33.8, 42.6, 51.6, 55.3]},
#  'Urban population': {'Year': [1962,
#    1967,
#    1972,
#    1977,
#    1982,
#    1987,
#    1992,
#    1997,
#    2002,
#    2007,
#    2012,
#    2015],
#   'Value': [804.9,
#    1066.0,
#    1434.0,
#    1888.0,
#    2045.0,
#    1935.0,
#    2608.0,
#    3872.0,
#    4866.0,
#    6215.0,
#    7596.0,
#    8547.0]},
#  'Urban population with access to safe drinking-water (JMP)': {'Year': [1992,
#    1997,
#    2002,
#    2007,
#    2012,
#    2015],
#   'Value': [43.0, 46.7, 55.9, 65.2, 74.5, 78.2]}}

# %%
afg_df.groupby(['country','Variable'])['Value'].count()
# Out:
# country      Variable
# Afghanistan  Population density                                           12
#              Rural population with access to safe drinking-water (JMP)     6
#              Total population                                             12
#              Total population with access to safe drinking-water (JMP)     6
#              Urban population                                             12
#              Urban population with access to safe drinking-water (JMP)     6
# Name: Value, dtype: int64

# %%
afg_meta_data = {}
for result in afg_results:
    print(result)
# Out:
# ('Afghanistan', 'Total population', 1962, 9344.0, 'E', 'AFG')
# ('Afghanistan', 'Total population', 1967, 10369.0, 'E', 'AFG')
# ('Afghanistan', 'Total population', 1972, 11717.0, 'E', 'AFG')
# ('Afghanistan', 'Total population', 1977, 13056.0, 'E', 'AFG')
# ('Afghanistan', 'Total population', 1982, 12667.0, 'E', 'AFG')
# ('Afghanistan', 'Total population', 1987, 11338.0, 'E', 'AFG')
# ('Afghanistan', 'Total population', 1992, 13746.0, 'E', 'AFG')
# ('Afghanistan', 'Total population', 1997, 18034.0, 'E', 'AFG')
# ('Afghanistan', 'Total population', 2002, 21487.0, 'E', 'AFG')
# ('Afghanistan', 'Total population', 2007, 25878.0, 'E', 'AFG')
# ('Afghanistan', 'Total population', 2012, 29727.0, 'E', 'AFG')
# ('Afghanistan', 'Total population', 2015, 32527.0, 'E', 'AFG')
# ('Afghanistan', 'Urban population', 1962, 804.9, 'E', 'AFG')
# ('Afghanistan', 'Urban population', 1967, 1066.0, 'E', 'AFG')
# ('Afghanistan', 'Urban population', 1972, 1434.0, 'E', 'AFG')
# ('Afghanistan', 'Urban population', 1977, 1888.0, 'E', 'AFG')
# ('Afghanistan', 'Urban population', 1982, 2045.0, 'E', 'AFG')
# ('Afghanistan', 'Urban population', 1987, 1935.0, 'E', 'AFG')
# ('Afghanistan', 'Urban population', 1992, 2608.0, 'E', 'AFG')
# ('Afghanistan', 'Urban population', 1997, 3872.0, 'E', 'AFG')
# ('Afghanistan', 'Urban population', 2002, 4866.0, 'E', 'AFG')
# ('Afghanistan', 'Urban population', 2007, 6215.0, 'E', 'AFG')
# ('Afghanistan', 'Urban population', 2012, 7596.0, 'E', 'AFG')
# ('Afghanistan', 'Urban population', 2015, 8547.0, 'E', 'AFG')
# ('Afghanistan', 'Population density', 1962, 14.31, 'E', 'AFG')
# ('Afghanistan', 'Population density', 1967, 15.88, 'E', 'AFG')
# ('Afghanistan', 'Population density', 1972, 17.95, 'E', 'AFG')
# ('Afghanistan', 'Population density', 1977, 20.0, 'E', 'AFG')
# ('Afghanistan', 'Population density', 1982, 19.4, 'E', 'AFG')
# ('Afghanistan', 'Population density', 1987, 17.37, 'E', 'AFG')
# ('Afghanistan', 'Population density', 1992, 21.06, 'E', 'AFG')
# ('Afghanistan', 'Population density', 1997, 27.62, 'E', 'AFG')
# ('Afghanistan', 'Population density', 2002, 32.91, 'E', 'AFG')
# ('Afghanistan', 'Population density', 2007, 39.64, 'E', 'AFG')
# ('Afghanistan', 'Population density', 2012, 45.53, 'E', 'AFG')
# ('Afghanistan', 'Population density', 2015, 49.82, 'E', 'AFG')
# ('Afghanistan', 'Total population with access to safe drinking-water (JMP)', 1992, 21.3, 'E', 'AFG')
# ('Afghanistan', 'Total population with access to safe drinking-water (JMP)', 1997, 25.0, 'E', 'AFG')
# ('Afghanistan', 'Total population with access to safe drinking-water (JMP)', 2002, 33.8, 'E', 'AFG')
# ('Afghanistan', 'Total population with access to safe drinking-water (JMP)', 2007, 42.6, 'E', 'AFG')
# ('Afghanistan', 'Total population with access to safe drinking-water (JMP)', 2012, 51.6, 'E', 'AFG')
# ('Afghanistan', 'Total population with access to safe drinking-water (JMP)', 2015, 55.3, 'E', 'AFG')
# ('Afghanistan', 'Rural population with access to safe drinking-water (JMP)', 1992, 16.2, 'E', 'AFG')
# ('Afghanistan', 'Rural population with access to safe drinking-water (JMP)', 1997, 19.5, 'E', 'AFG')
# ('Afghanistan', 'Rural population with access to safe drinking-water (JMP)', 2002, 27.6, 'E', 'AFG')
# ('Afghanistan', 'Rural population with access to safe drinking-water (JMP)', 2007, 35.6, 'E', 'AFG')
# ('Afghanistan', 'Rural population with access to safe drinking-water (JMP)', 2012, 43.7, 'E', 'AFG')
# ('Afghanistan', 'Rural population with access to safe drinking-water (JMP)', 2015, 47.0, 'E', 'AFG')
# ('Afghanistan', 'Urban population with access to safe drinking-water (JMP)', 1992, 43.0, 'E', 'AFG')
# ('Afghanistan', 'Urban population with access to safe drinking-water (JMP)', 1997, 46.7, 'E', 'AFG')
# ('Afghanistan', 'Urban population with access to safe drinking-water (JMP)', 2002, 55.9, 'E', 'AFG')
# ('Afghanistan', 'Urban population with access to safe drinking-water (JMP)', 2007, 65.2, 'E', 'AFG')
# ('Afghanistan', 'Urban population with access to safe drinking-water (JMP)', 2012, 74.5, 'E', 'AFG')
# ('Afghanistan', 'Urban population with access to safe drinking-water (JMP)', 2015, 78.2, 'E', 'AFG')

# %%
for result in afg_results:
    if result[1]=='Total population':
        print(result)
# Out:
# ('Afghanistan', 'Total population', 1962, 9344.0, 'E', 'AFG')
# ('Afghanistan', 'Total population', 1967, 10369.0, 'E', 'AFG')
# ('Afghanistan', 'Total population', 1972, 11717.0, 'E', 'AFG')
# ('Afghanistan', 'Total population', 1977, 13056.0, 'E', 'AFG')
# ('Afghanistan', 'Total population', 1982, 12667.0, 'E', 'AFG')
# ('Afghanistan', 'Total population', 1987, 11338.0, 'E', 'AFG')
# ('Afghanistan', 'Total population', 1992, 13746.0, 'E', 'AFG')
# ('Afghanistan', 'Total population', 1997, 18034.0, 'E', 'AFG')
# ('Afghanistan', 'Total population', 2002, 21487.0, 'E', 'AFG')
# ('Afghanistan', 'Total population', 2007, 25878.0, 'E', 'AFG')
# ('Afghanistan', 'Total population', 2012, 29727.0, 'E', 'AFG')
# ('Afghanistan', 'Total population', 2015, 32527.0, 'E', 'AFG')

# %%
for isso in (set(aqua_df.iso)-set(wqi_df.iso)):
    print(aqua_df.loc[aqua_df['iso']==isso]['country'].iloc[0])
    print(aqua_df.loc[aqua_df['iso']==isso]['iso'].iloc[0])
    print('######################################################')
# Out:
# Yemen
# YEM
# ######################################################
# Tuvalu
# TUV
# ######################################################
# San Marino
# SMR
# ######################################################
# Saint Kitts and Nevis
# KNA
# ######################################################
# Syrian Arab Republic
# SYR
# ######################################################
# South Sudan
# SSD
# ######################################################
# Somalia
# SOM
# ######################################################
# Faroe Islands
# FRO
# ######################################################
# Democratic People's Republic of Korea
# PRK
# ######################################################
# Cook Islands
# COK
# ######################################################
# Holy See
# VAT
# ######################################################
# Monaco
# MCO
# ######################################################
# Liechtenstein
# LIE
# ######################################################
# Andorra
# AND
# ######################################################
# Puerto Rico
# PRI
# ######################################################
# Tokelau
# TKL
# ######################################################
# Occupied Palestinian Territory
# PSE
# ######################################################
# Marshall Islands
# MHL
# ######################################################
# Nauru
# NRU
# ######################################################
# Niue
# NIU
# ######################################################
# Palau
# PLW
# ######################################################

# %%
engine.execute('SELECT * FROM WQITable LIMIT 10').fetchall()
# Out:
# [(0, 'AFG', 'Afghanistan', 25.75),
#  (1, 'ALB', 'Albania', 66.56),
#  (2, 'DZA', 'Algeria', 60.26),
#  (3, 'AGO', 'Angola', 9.2),
#  (4, 'ATG', 'Antigua and Barbuda', 53.33),
#  (5, 'ARG', 'Argentina', 73.07),
#  (6, 'ARM', 'Armenia', 61.94),
#  (7, 'AUS', 'Australia', 98.44),
#  (8, 'AUT', 'Austria', 94.63),
#  (9, 'AZE', 'Azerbaijan', 48.53)]

# %%
engine.execute('SELECT * FROM AquastatTable LIMIT 10').fetchall()
# Out:
# [(0, 'Afghanistan', 'Total population', 1962, 9344.0, 'E', 'AFG'),
#  (1, 'Afghanistan', 'Total population', 1967, 10369.0, 'E', 'AFG'),
#  (2, 'Afghanistan', 'Total population', 1972, 11717.0, 'E', 'AFG'),
#  (3, 'Afghanistan', 'Total population', 1977, 13056.0, 'E', 'AFG'),
#  (4, 'Afghanistan', 'Total population', 1982, 12667.0, 'E', 'AFG'),
#  (5, 'Afghanistan', 'Total population', 1987, 11338.0, 'E', 'AFG'),
#  (6, 'Afghanistan', 'Total population', 1992, 13746.0, 'E', 'AFG'),
#  (7, 'Afghanistan', 'Total population', 1997, 18034.0, 'E', 'AFG'),
#  (8, 'Afghanistan', 'Total population', 2002, 21487.0, 'E', 'AFG'),
#  (9, 'Afghanistan', 'Total population', 2007, 25878.0, 'E', 'AFG')]
